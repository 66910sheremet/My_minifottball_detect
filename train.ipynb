# %%
from ultralytics import YOLO

model = YOLO('yolov10n.pt')

results = model.train(data='mini_to_yolo\data.yaml', epochs=1, imgsz=640)
# Out:
# Ultralytics YOLOv8.2.82  Python-3.9.13 torch-2.4.0+cpu CPU (13th Gen Intel Core(TM) i7-13700H)
# ...
